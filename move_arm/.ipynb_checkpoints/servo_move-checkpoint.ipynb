# %%
#!/usr/bin/env python3
#coding=utf-8
import time
from Arm_Lib import Arm_Device
import numpy as np
#オブジェクト作成
Arm = Arm_Device()
time.sleep(.1)

# %%
#idとラベルの数字が対応している
#安全のために可能な限りtimeは大きい値で
#Arm_serial_servo_write6(id1, id2, id3, id4, id5, id6, time)
Arm.Arm_serial_servo_write6(90, 90, 90, 90, 90, 90, 1000)
time.sleep(2)

# %%
#各サーボの角度を取得
for id in range(6):
    arm_position=Arm.Arm_serial_servo_read_any(id+1)
    print(f'{id+1} arm position {arm_position}')
# Out:
# 1 arm position 89
# 2 arm position 90
# 3 arm position 90
# 4 arm position 90
# 5 arm position 48
# 6 arm position 90
